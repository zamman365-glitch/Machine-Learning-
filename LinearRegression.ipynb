# %% [markdown]
# <a href="https://colab.research.google.com/github/zamman365-glitch/Machine-Learning-/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.shape
# Out:
# (891, 15)

# %%
# x = Input Features/Predictors
# Y = output

# %%
x = df.drop('survived', axis = 1) # Output cloumn ko baki sare column

# %%
y = df['survived'] # Only output column

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test, y_train, y_test = train_test_split(x,y)

# %%
#Objective type value convert --> Numeric
